# %% [markdown]
# # Content Creation with CrewAI
#
# Welcome to the first practice lab of this course!
#
# In this lab , you'll see an example of using CrewAI for content creation. This demonstrates how to build a single-agent system for planning YouTube Shorts content.
#
# **What you'll see:**
# - How to define an agent with a specific content creation role
# - How to create a task with structured output requirements
# - How to assemble an agent and task into a crew
# - How CrewAI executes the workflow
#
# **What this example builds:**
# A **Content Planning Agent** that creates a weekly content calendar for YouTube Shorts focusing on micro-history topics.
#
# ## Background
#
# You're a content creator focusing on short-form video content about the surprising origins of everyday things. You want to create engaging 30-45 second YouTube Shorts that:
# - Hooks viewers in the first second
# - Tells a clear story with a surprising twist
# - Drives engagement through comments
# - Can be filmed at home with minimal equipment
#
# Instead of manually brainstorming and planning content, you'll use an AI agent to generate a structured weekly content plan.
#
# ## General instructions
# In this lab you will be presented with a structure of the code, but you will need to complete some of it.
#
# To successfully run this lab, replace all instances of the placeholder `None` with your own code. Sections where you need to write code will be delimited between `### START CODE HERE ###` and `### END CODE HERE ###`.
#
# **<font color='#5DADEC'>Please make sure to save your work periodically, so you don't lose any progress.</font>**

# %% [markdown]
# ## Table of Contents
#
# - [1. Set Up Your Notebook](#1)
# - [2. Define the Content Planning Agent](#2)
# - [3. Define the Content Planning Task](#3)
# - [4. Create and Run the Crew](#4)
# - [5. Review the Results](#5)

# %% [markdown]
# <a id="1"></a>
#
# ## 1. Set Up Your Notebook
#
# First, import the necessary modules and configure the environment.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from crewai import Task, Agent, Crew
import os
os.environ["CREWAI_TESTING"] = "true"
from utils import get_openai_api_key

os.environ["OPENAI_API_KEY"] = get_openai_api_key()

# %% [markdown]
# <a id="2"></a>
#
# ## 2. Define the Content Planning Agent
#
# Content creation is an excellent use case for AI agents because it involves:
# - **Strategy**: Understanding platform requirements and audience psychology
# - **Creativity**: Generating engaging hooks and concepts
# - **Structure**: Organizing content in a repeatable, scalable format
#
# In this example, you'll create a single specialized agent:
#
# **Content Planning Agent:**
# - Plans a weekly slate of video concepts
# - Ensures each video follows best practices for retention
# - Keeps ideas practical and filmable for a solo creator
#
# The agent will produce a structured JSON output with video blueprints that include titles, hooks, visual ideas, tags, and calls-to-action.
#
# Agents in CrewAI represent team members with specific roles, goals, and expertise. Each agent has:
# - **Role**: Their job title or function
# - **Goal**: What they aim to achieve
# - **Backstory**: Their experience and expertise. This helps the LLM understand how to roleplay the agent.
# - **LLM**: The language model to use (in this case, gpt-4o-mini)
# - **Verbose**: Whether to show detailed output (useful for learning and debugging)
#
# Use the next cell to create your very own agent! Try following best practices, as shown by João.

# %%
# Define the Content Planning Agent
content_creator_assistant = Agent(
    ### START CODE HERE
    role="Content Creator Assistant",
    goal="Come up with video ideas",
    backstory="Someone who has a lot of experience creating video contnet",
    llm="gpt-4o",
    verbose=True,
    ### END CODE HERE ###
)

print("✓ Content planning agent defined")
# Out:
# ✓ Content planning agent defined

# %% [markdown]
# <a id="3"></a>
#
# ## 3. Define the Content Planning Task
#
# Tasks define the actual work that agents will perform. Each task has:
# - **Description**: What needs to be done, including context and requirements
# - **Expected Output**: What the result should look like (in this case, a JSON schema)
# - **Agent**: Which agent will perform this task
#
# Let's create a task that generates a weekly content plan with structured video blueprints. Once again, try using best practices to fill in the fields.

# %%
# Define the Content Planning Task
task = Task(
    ### START CODE HERE ###
    description="Come up with 5 new video ideas",
    expected_output="List of ideas",
    agent=content_creator_assistant
    ### END CODE HERE ###
)

print("✓ Content planning task defined")
# Out:
# ✓ Content planning task defined

# %% [markdown]
# <a id="4"></a>
#
# ## 4. Create and Run the Crew
#
# Now you'll assemble the agent and task into a **Crew**. Even with a single agent, CrewAI provides a structured way to organize and execute the workflow.
#
# The crew will:
# 1. Execute the task using the agent
# 2. Use the LLM to power agent reasoning and content generation
# 3. Return structured output according to the expected format

# %%
# Create the content planning crew
crew = Crew(
    ### START CODE HERE ###
    agents=[content_creator_assistant],
    tasks=[task],
    ### END CODE HERE ###
)

print("✓ Content planning crew created")
print("\n🚀 Starting content planning...\n")

# Execute the crew's task
result = crew.kickoff()

print("\n✓ Content planning complete!")
# Out:
# ✓ Content planning crew created
#
# 🚀 Starting content planning...
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Creator Assistant                                                                               │
# │                                                                                                                 │
# │  Task: Come up with 5 new video ideas                                                                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Creator Assistant                                                                               │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  1. **Virtual Reality Experiences: A Journey into the Future**                                                  │
# │     - Concept: Explore various virtual reality technologies and experiences that are shaping entertainment,     │
# │  education, and work environments. Interview VR enthusiasts, developers, and users to give viewers a            │
# │  comprehensive look into this evolving world.                                                                   │
# │                                                                                                                 │
# │  2. **The Science of Sleep: Tips for a Restful Night**                                                          │
# │     - Concept: Discuss the importance of sleep and its impact on health, productivity, and daily life. Include  │
# │  interviews with sleep specialists, scientists, and individuals who have optimized their sleep patterns.        │
# │  Provide actionable tips and techniques viewers can use to improve their sleep quality.                         │
# │                                                                                                                 │
# │  3. **A Day in the Life of a Wildlife Photographer**                                                            │
# │     - Concept: Follow a wildlife photographer on a shoot, capturing the challenges and excitement of            │
# │  photographing animals in their natural habitats. Include behind-the-scenes footage, tips for aspiring          │
# │  photographers, and highlight the importance of conservation efforts.                                           │
# │                                                                                                                 │
# │  4. **Myth-Busting: Popular Internet Myths Debunked**                                                           │
# │     - Concept: Investigate and debunk popular myths circulating the internet. Use expert opinions, scientific   │
# │  evidence, and entertaining visuals to set the record straight on common misconceptions. Invite viewers to      │
# │  engage with their own myths for future episodes.                                                               │
# │                                                                                                                 │
# │  5. **Sustainable Fashion: Eco-Friendly Shopping Haul**                                                         │
# │     - Concept: Showcase how to create a stylish wardrobe while being mindful of sustainability. Explore         │
# │  various eco-friendly fashion brands, highlight the environmental impact of fast fashion, and provide viewers   │
# │  with tips on thrifting, upcycling, and ethical consumption.                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ✓ Content planning complete!

# %% [markdown]
# <a id="5"></a>
#
# ## 5. Review the Results
#
# Let's examine the output from the content planning task. The agent should have generated a structured JSON with 5 video blueprints for the week.

# %%
# Display the content plan
print("=" * 80)
print("WEEKLY CONTENT PLAN")
print("=" * 80)
print(result.raw)
# Out:
# ================================================================================
# WEEKLY CONTENT PLAN
# ================================================================================
# 1. **Virtual Reality Experiences: A Journey into the Future**
#    - Concept: Explore various virtual reality technologies and experiences that are shaping entertainment, education, and work environments. Interview VR enthusiasts, developers, and users to give viewers a comprehensive look into this evolving world.
#
# 2. **The Science of Sleep: Tips for a Restful Night**
#    - Concept: Discuss the importance of sleep and its impact on health, productivity, and daily life. Include interviews with sleep specialists, scientists, and individuals who have optimized their sleep patterns. Provide actionable tips and techniques viewers can use to improve their sleep quality.
#
# 3. **A Day in the Life of a Wildlife Photographer**
#    - Concept: Follow a wildlife photographer on a shoot, capturing the challenges and excitement of photographing animals in their natural habitats. Include behind-the-scenes footage, tips for aspiring photographers, and highlight the importance of conservation efforts.
#
# 4. **Myth-Busting: Popular Internet Myths Debunked**
#    - Concept: Investigate and debunk popular myths circulating the internet. Use expert opinions, scientific evidence, and entertaining visuals to set the record straight on common misconceptions. Invite viewers to engage with their own myths for future episodes.
#
# 5. **Sustainable Fashion: Eco-Friendly Shopping Haul**
#    - Concept: Showcase how to create a stylish wardrobe while being mindful of sustainability. Explore various eco-friendly fashion brands, highlight the environmental impact of fast fashion, and provide viewers with tips on thrifting, upcycling, and ethical consumption.

# %% [markdown]
# Congratulations! You've successfully finished this lab. See you in the next one. 🚀

# %% [markdown]
# ## Context Engineering을 기반으로 Agent와 Taks를 다시 정의함

# %%
# Define the Content Planning Agent based on Context Engineering principles
content_creator_assistant = Agent(
    ### START CODE HERE
    role="YouTube Shorts Micro-History Strategist",
    goal="Plan a 1-week slate of high-retention YouTube Shorts about surprising origins ",
    backstory="Someone who has a lot of experience creating video contnet",
    llm="gpt-4o",
    verbose=True,
    ### END CODE HERE ###
)

print("✓ Content planning agent defined")

# %%
# Define the Content Planning Task based on Context Engineering principles
task = Task(
    ### START CODE HERE ###
    description=(
        "Creating a 1-week video posting plan with 5 video blueprints. " 
        "Platform: YouTube Shorts (vertical 9:16, 30-45ㄴ). " 
        "Niche: Micro-History of Everday Things (e.g., Why pencils are yeloow, origin of high-fives). "
        "3) strong SEO phrasing in a title/caption, 4) comment-bait CTA." 
        "Context: slol creator, home-filmable, no special gear." 
    ),
    expected_output=( 
        '''
        Output a JSON array following the schema below, which contains a 
        weekly schedule and 5 video blueprints. Each video blueprint should include: 
        { 
            "videos": [
                { 
                    "title": "<searchable, curiosity-driven title>",
                    "hook_main": "<<=12 words, shows payoff fast>", 
                    "hook_alt": "<variant hook>", 
                    "visuals": ["simple prop or b-roll idea 1", "idea 2"], 
                    "tags": ["#microhistory", "#everdaythings", "#shorts"],
                    "cta": "<question that invites comments>"
                }
            ]
        }
        '''
    ),
    agent=content_creator_assistant
    ### END CODE HERE ###
)

print("✓ Content planning task defined")
# Out:
# ✓ Content planning task defined

# %%
# Create the content planning crew
crew = Crew(
    ### START CODE HERE ###
    agents=[content_creator_assistant],
    tasks=[task],
    ### END CODE HERE ###
)

print("✓ Content planning crew created")
print("\n🚀 Starting content planning...\n")

# Execute the crew's task
result = crew.kickoff()

print("\n✓ Content planning complete!")
# Out:
# ✓ Content planning crew created
#
# 🚀 Starting content planning...
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Creator Assistant                                                                               │
# │                                                                                                                 │
# │  Task: Creating a 1-week video posting plan with 5 video blueprints. Platform: YouTube Shorts (vertical 9:16,   │
# │  30-45ㄴ). Niche: Micro-History of Everday Things (e.g., Why pencils are yeloow, origin of high-fives). 3)      │
# │  strong SEO phrasing in a title/caption, 4) comment-bait CTA.Context: slol creator, home-filmable, no special   │
# │  gear.                                                                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Creator Assistant                                                                               │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  ```json                                                                                                        │
# │  {                                                                                                              │
# │      "videos": [                                                                                                │
# │          {                                                                                                      │
# │              "title": "Why Are Pencils Yellow? The Surprising Origin",                                          │
# │              "hook_main": "Why are most pencils yellow? Discover now!",                                         │
# │              "hook_alt": "Ever wonder why pencils are yellow? Find out!",                                       │
# │              "visuals": ["Close-up of a yellow pencil", "Person drawing with a pencil"],                        │
# │              "tags": ["#microhistory", "#everydaythings", "#shorts"],                                           │
# │              "cta": "What's your favorite pencil color?"                                                        │
# │          },                                                                                                     │
# │          {                                                                                                      │
# │              "title": "The Secret History of the High-Five",                                                    │
# │              "hook_main": "Ready for a high-five history lesson?",                                              │
# │              "hook_alt": "Ever asked how high-fives started? Here's how!",                                      │
# │              "visuals": ["Two people high-fiving", "Historical high-five photos"],                              │
# │              "tags": ["#microhistory", "#everydaythings", "#shorts"],                                           │
# │              "cta": "Who do you high-five most often?"                                                          │
# │          },                                                                                                     │
# │          {                                                                                                      │
# │              "title": "Why Do We Say 'Hello' on the Phone?",                                                    │
# │              "hook_main": "Discover why 'Hello' is the phone greeting!",                                        │
# │              "hook_alt": "What made 'Hello' the universal phone greeting?",                                     │
# │              "visuals": ["People talking on vintage phones", "Text bubble saying 'Hello'"],                     │
# │              "tags": ["#microhistory", "#everydaythings", "#shorts"],                                           │
# │              "cta": "Do you use any unique phone greetings?"                                                    │
# │          },                                                                                                     │
# │          {                                                                                                      │
# │              "title": "The Unexpected Origin of Blue Jeans",                                                    │
# │              "hook_main": "Jeans were once work clothes. Find out more!",                                       │
# │              "hook_alt": "Why are jeans a wardrobe staple? Learn now!",                                         │
# │              "visuals": ["Close-up of denim", "Person wearing classic blue jeans"],                             │
# │              "tags": ["#microhistory", "#everydaythings", "#shorts"],                                           │
# │              "cta": "What's your favorite jean style?"                                                          │
# │          },                                                                                                     │
# │          {                                                                                                      │
# │              "title": "How Did Ice Cream Cones Become So Popular?",                                             │
# │              "hook_main": "The true scoop on ice cream cones begins here!",                                     │
# │              "hook_alt": "Have you wondered where cones come from? Look!",                                      │
# │              "visuals": ["Scoop of ice cream on a cone", "People eating ice cream cones"],                      │
# │              "tags": ["#microhistory", "#everydaythings", "#shorts"],                                           │
# │              "cta": "Cone or cup: How do you enjoy your ice cream?"                                             │
# │          }                                                                                                      │
# │      ]                                                                                                          │
# │  }                                                                                                              │
# │  ```                                                                                                            │
# │                                                                                                                 │
# │  This JSON array provides a week's video posting plan with engaging video blueprints that include searchable    │
# │  titles, hooks, visual ideas, and comment-bait CTAs.                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ✓ Content planning complete!

# %%
# Display the content plan
print("=" * 80)
print("WEEKLY CONTENT PLAN")
print("=" * 80)
print(result.raw)
# Out:
# ================================================================================
# WEEKLY CONTENT PLAN
# ================================================================================
# ```json
# {
#     "videos": [
#         {
#             "title": "Why Are Pencils Yellow? The Surprising Origin",
#             "hook_main": "Why are most pencils yellow? Discover now!",
#             "hook_alt": "Ever wonder why pencils are yellow? Find out!",
#             "visuals": ["Close-up of a yellow pencil", "Person drawing with a pencil"],
#             "tags": ["#microhistory", "#everydaythings", "#shorts"],
#             "cta": "What's your favorite pencil color?"
#         },
#         {
#             "title": "The Secret History of the High-Five",
#             "hook_main": "Ready for a high-five history lesson?",
#             "hook_alt": "Ever asked how high-fives started? Here's how!",
#             "visuals": ["Two people high-fiving", "Historical high-five photos"],
#             "tags": ["#microhistory", "#everydaythings", "#shorts"],
#             "cta": "Who do you high-five most often?"
#         },
#         {
#             "title": "Why Do We Say 'Hello' on the Phone?",
#             "hook_main": "Discover why 'Hello' is the phone greeting!",
#             "hook_alt": "What made 'Hello' the universal phone greeting?",
#             "visuals": ["People talking on vintage phones", "Text bubble saying 'Hello'"],
#             "tags": ["#microhistory", "#everydaythings", "#shorts"],
#             "cta": "Do you use any unique phone greetings?"
#         },
#         {
#             "title": "The Unexpected Origin of Blue Jeans",
#             "hook_main": "Jeans were once work clothes. Find out more!",
#             "hook_alt": "Why are jeans a wardrobe staple? Learn now!",
#             "visuals": ["Close-up of denim", "Person wearing classic blue jeans"],
#             "tags": ["#microhistory", "#everydaythings", "#shorts"],
#             "cta": "What's your favorite jean style?"
#         },
#         {
#             "title": "How Did Ice Cream Cones Become So Popular?",
#             "hook_main": "The true scoop on ice cream cones begins here!",
#             "hook_alt": "Have you wondered where cones come from? Look!",
#             "visuals": ["Scoop of ice cream on a cone", "People eating ice cream cones"],
#             "tags": ["#microhistory", "#everydaythings", "#shorts"],
#             "cta": "Cone or cup: How do you enjoy your ice cream?"
#         }
#     ]
# }
# ```
#
# This JSON array provides a week's video posting plan with engaging video blueprints that include searchable titles, hooks, visual ideas, and comment-bait CTAs.
